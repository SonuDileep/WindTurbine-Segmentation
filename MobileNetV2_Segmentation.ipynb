# %% [markdown]
# **Image Segmentation is a deep learning problem where we assign a class or label to each individual pixels. There are many different models for image segmentation. Here I am trying to build a model for wind turbine segmentation. For this particular task I used an encoder-decoder architecture using a pretrained MobileNetV2 architecture. The dataset used for training the model is given by SkySpecs. Few data augmentation techniques are used to train the model. The model is finally tested on a windturbine inspection dataset from DTU - Drone inspection images of wind
# turbine.**

# %% [markdown]
# Packages used:
# Tensorflow 2.x, OpenCV 3.x or 4.x, Numpy, Keras, Matplotlib, Scikit-Learn, Scikit_Image, TensorFlow-example. If you are using google colab to run the code, all package are preinstalled except TensorFlow-example .
#
# ---

# %% [markdown]
# By Sonu Dileep

# %%
# Allow colab to access files in Drive. Comment it when running locally
from google.colab import drive
drive.mount('/content/drive')

# Install TensorFlow-example to load Pix2Pix
# !pip install git+https://github.com/tensorflow/examples.git
# Out:
# Mounted at /content/drive
# Collecting git+https://github.com/tensorflow/examples.git
#   Cloning https://github.com/tensorflow/examples.git to /tmp/pip-req-build-zqjcu4wv
#   Running command git clone -q https://github.com/tensorflow/examples.git /tmp/pip-req-build-zqjcu4wv
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-examples===ff4ddd4609f76d8b7d085033a9b4cd9a3c6d26bd-) (0.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorflow-examples===ff4ddd4609f76d8b7d085033a9b4cd9a3c6d26bd-) (1.15.0)
# Building wheels for collected packages: tensorflow-examples
#   Building wheel for tensorflow-examples (setup.py) ... done
#   Created wheel for tensorflow-examples: filename=tensorflow_examples-ff4ddd4609f76d8b7d085033a9b4cd9a3c6d26bd_-cp36-none-any.whl size=164220 sha256=e2c0788a88f2555b11855ab9ead158485df6f60bc4bec481843caa466962e251
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kbs7tadu/wheels/83/64/b3/4cfa02dc6f9d16bf7257892c6a7ec602cd7e0ff6ec4d7d714d
# Successfully built tensorflow-examples
# Installing collected packages: tensorflow-examples
# Successfully installed tensorflow-examples-ff4ddd4609f76d8b7d085033a9b4cd9a3c6d26bd-

# %%
#Import required libraries
import tensorflow as tf
from keras.preprocessing import image 
from tensorflow_examples.models.pix2pix import pix2pix
from keras.callbacks import ModelCheckpoint


import os
import cv2
import copy
import numpy as np  
import matplotlib.pyplot as plt
from skimage.transform import rotate
from IPython.display import clear_output
from sklearn.model_selection import train_test_split

# %%
# Load input image and mask path to a list
input_dir = "/content/drive/My Drive/SkySpecs/Images/" #input folder path
mask_dir = "/content/drive/My Drive/SkySpecs/Segmentation-Outputs/" # mask folder path
input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".jpg")
    ]
)
target_img_paths = sorted(
    [
        os.path.join(mask_dir, fname)
        for fname in os.listdir(mask_dir)
        if fname.endswith(".png") 
    ]
)

print("Number of samples:", len(input_img_paths))
# Out:
# Number of samples: 147

# %%
#Load input and mask images to memory
x_input = [] 
x_mask = []
img_size = 224 # Specify input size of the deep learning model (for mobilenetV2 maximum size is 224)

#To get input Images
for i in range(0,len(input_img_paths)): 
	img_path = input_img_paths[i] 
	temp_img = cv2.imread(img_path)
	temp_img = cv2.resize(temp_img,(img_size,img_size))  
	x_input.append(temp_img) #Append each image to x_input list
 
# To get mask images 
for i in range(0,len(target_img_paths)): 
	img_path = target_img_paths[i] 
	temp_img = cv2.imread(img_path,0) 
	(thresh, temp_img) = cv2.threshold(temp_img, 127, 255, cv2.THRESH_BINARY) #Binary Conversion. 0's for background and 1's for mask
	temp_img = cv2.resize(temp_img,(img_size,img_size))
	x_mask.append(temp_img) #Append each mask to x_mask list

# %%
# Check whether mask and input images are ordered correctly
i = 69
plt.subplot(1, 2, 1)
plt.imshow(x_input[i])
plt.subplot(1, 2, 2)
plt.imshow(x_mask[i])

# %%
#Pre-processing - Image Normalization
x_input = np.asarray(x_input) #Convert to numpy array
x_mask = np.asarray(x_mask) #Convert to numpy array


x_input = x_input/255.0 #Normalize each image so that pixel values lie between 0 and 1
x_mask = x_mask/255 
x_mask = x_mask.astype(np.uint8) #Convert the mask image to uint8 so that the values are either 0 or 1

# %% [markdown]
# Keep 80% of the data for training and rest 20% for training

# %%
# Split the dataset into training and testing
seed = 4
x_train, x_test, y_train, y_test = train_test_split(x_input, x_mask, test_size = 0.20, random_state=seed) # Adjust the test_size to change testing data size

# %% [markdown]
# **Data Augmentation**
# The data augmentation techniques used here are Flipping and Rotation. The image is flipped both horizontally and vertically. The images are rotated by 30, 45, 60 and 90 degree.

# %%
#Data Augmentations - Flipping and Rotations
from skimage.transform import rotate
def img_flip(x_train,y_train): # Function to flip images vertically and horizontally
    X_trainv = np.flipud(x_train) #Vertical flip
    X_trainh = np.fliplr(x_train) #Horizontal flip
    X_train_total = np.concatenate([x_train, X_trainv, X_trainh])

    Y_trainv = np.flipud(y_train)
    Y_trainh = np.fliplr(y_train)
    Y_train_total = np.concatenate([y_train, Y_trainv, Y_trainh])
    return X_train_total, Y_train_total # Returns input and mask images flipped

def img_rotate(X_train,Y_train): # Function to rotate images by 30, 45, 60 and 90 degree
    temp_img = []
    temp_mask = []
    for i in range(len(X_train)):
      img = X_train[i]
      img_mask = Y_train[i]
      rotate30 = rotate(img, angle=30)
      rotate45 = rotate(img, angle=45)
      rotate60 = rotate(img, angle=60)
      rotate90 = rotate(img, angle=90)
    
      rotate30_mask = rotate(img_mask, angle=30)
      rotate45_mask = rotate(img_mask, angle=45)
      rotate60_mask = rotate(img_mask, angle=60)
      rotate90_mask = rotate(img_mask, angle=90)

      temp_img.extend([rotate30, rotate45, rotate60, rotate90])
      temp_mask.extend([rotate30_mask, rotate45_mask, rotate60_mask, rotate90_mask ])
    return temp_img, temp_mask # Return rotated input and mask image

m,n = img_rotate(x_train, y_train)
m1,n1 = img_flip(x_train, y_train)
print("Number of Flipped images + input images : ",len(m1))
print("Number of Rotated images : ",len(m))
# Out:
# Number of Flipped images + input images :  351
# Number of Rotated images :  468

# %%
#Convert to numpy array and concatenate flipped and rotated images
rotate_input = np.asarray(m)
rotate_mask = np.asarray(n)
flip_input = np.asarray(m1)
flip_mask = np.asarray(n1)
x_train = np.concatenate([rotate_input, flip_input])
y_train = np.concatenate([rotate_mask, flip_mask])
print("Total Size of Training set : ",x_train.shape[0])
# Out:
# Total Size of Training set :  819

# %%
# Check whether mask and input images are ordered correctly
i = 200
plt.subplot(1, 2, 1)
plt.imshow(x_train[i])
plt.subplot(1, 2, 2)
plt.imshow(y_train[i])
y_train = y_train.astype(np.uint8)

# %% [markdown]
# **Architecture**
#
# For Segmentation, I used an Encoder-Decoder Architecture. Encoder-Decoder model tries to learn the semantic information from the image and has the advantage of giving better result in cases with few training samples. I used a MobileNetV2 trained on imagenet as an encoder. Encoder transforms the input image into a feature vector. MobileNetV2 is a mobile model for embedded devices and it trains fast and also the inference speed is faster compared to other models. The decoder is an upsample block implemented using pix2pix. Pix2Pix is an architecture used for training a Deep CNN which helps in image to image translations. Tensorflow-examples has an implementation of pix2pix which can be used for this task. The outputs from intermediate layers of Encoder are passed to the Decoder. The last layer of decoder outputs the segmentation mask.
#
# Note :  Encoders are not trained during the training.

# %%
mobilenet = tf.keras.applications.MobileNetV2(input_shape=[img_size, img_size, 3], include_top=False,weights="imagenet") # Define MobileNetV2 as an encoder and initialize weights from imagenet 
layer_names = [                             # Activations from these layers are passed to decoder network. Block_16_project is the final layer in encoder and rest of the layers are the layers                                
    'block_1_expand_relu',   # 112x112      # before downsampling of tensors. These layers contain the most information about image features.
    'block_3_expand_relu',   # 56x56
    'block_6_expand_relu',   # 28x28
    'block_13_expand_relu',  # 14x14
    'block_16_project']      # 7x7
layers = [mobilenet.get_layer(name).output for name in layer_names] # Stores the output features from layers mentioned above
encoder = tf.keras.Model(inputs=mobilenet.input, outputs=layers) # A model is defined with inputs and outputs. Input is the image and outputs are output features from 5 layers defined above.
encoder.trainable = False # Set the encoder model as non-trainable
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step

# %%
# Define the upsampler blocks/decoder using pix2pix
decoder = [
    pix2pix.upsample(512, 3),  # Upsamples 7x7 features from block_16_project layer to 14x14. 512 is the number of Convolutional filters and 3 number of channels in input image
    pix2pix.upsample(256, 3),  # Upsamples 14x14 features from block_16_project layer to 28x28.
    pix2pix.upsample(128, 3),  # Upsamples 28x28 features from block_16_project layer to 56x56.
    pix2pix.upsample(64, 3),   # Upsamples 56x56 features from block_16_project layer to 112x112.
]

# %%
#Stack both encoder and decoder into a single model
def seg_turbine(): # Returns the encoder-decoder model
  output_channels = 1 # Number of output channels = 1  (binary mask image)
  inputs = tf.keras.layers.Input(shape=[img_size, img_size, 3]) # Specify the input image size and number of channels

  # Downsampling through the model
  skips = encoder(inputs)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(decoder, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()
    x = concat([x, skip])

  # Final layer in the model which outputs a 224 x224 mask image
  last = tf.keras.layers.Conv2DTranspose(
      output_channels, 2, strides=2,
      padding='same')  #112x112 -> 224x224

  x = last(x)
  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
def dice_loss(y_true, y_pred):
  y_true = tf.cast(y_true, tf.float32)
  y_pred = tf.math.sigmoid(y_pred)
  numerator = 2 * tf.reduce_sum(y_true * y_pred)
  denominator = tf.reduce_sum(y_true + y_pred)
  return 1 - numerator / denominator

# %%
# Compile the model with adam optimizer and binary_crossentropy loss function. Since we are dealing with a binary image and 
# there are only 2 classes (wind turbine and background) we can use binary_crossentropy. here I used validation accuracy as metric. One other metric that could be used here is IoU loss
model = seg_turbine() # initialize the model
#model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), metrics='accuracy')
model.compile(optimizer='adam', loss=dice_loss, metrics=dice_loss)

# %%
tf.keras.utils.plot_model(model, show_shapes=True) # To visualize the entire model

# %%
#Set the number of epochs and batch size 
EPOCHS = 500
BATCH_SIZE = 64 
checkpointer = ModelCheckpoint('/content/drive/My Drive/SkySpecs/507_1.h5', monitor='val_dice_loss', verbose=1, save_best_only=True, mode='min')
model_history = model.fit(x_train,y_train, epochs=EPOCHS, batch_size = BATCH_SIZE, callbacks=[checkpointer],validation_data=(x_test,y_test))
# Out:
# Epoch 1/500
#  2/13 [===>..........................] - ETA: 0s - loss: 0.8371 - dice_loss: 0.8371WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0358s vs `on_train_batch_end` time: 0.0852s). Check your callbacks.
# 13/13 [==============================] - ETA: 0s - loss: 0.7823 - dice_loss: 0.7818
# Epoch 00001: val_dice_loss improved from inf to 0.49716, saving model to /content/drive/My Drive/SkySpecs/507_1.h5
# 13/13 [==============================] - 6s 442ms/step - loss: 0.7823 - dice_loss: 0.7818 - val_loss: 0.4972 - val_dice_loss: 0.4972
# Epoch 2/500
# 13/13 [==============================] - ETA: 0s - loss: 0.6108 - dice_loss: 0.6097
# Epoch 00002: val_dice_loss improved from 0.49716 to 0.42368, saving model to /content/drive/My Drive/SkySpecs/507_1.h5
# 13/13 [==============================] - 2s 150ms/step - loss: 0.6108 - dice_loss: 0.6097 - val_loss: 0.4237 - val_dice_loss: 0.4237
# Epoch 3/500
# 13/13 [==============================] - ETA: 0s - loss: 0.3642 - dice_loss: 0.3633
# Epoch 00003: val_dice_loss improved from 0.42368 to 0.29238, saving model to /content/drive/My Drive/SkySpecs/507_1.h5
# 13/13 [==============================] - 2s 157ms/step - loss: 0.3642 - dice_loss: 0.3633 - val_loss: 0.2924 - val_dice_loss: 0.2924
# Epoch 4/500
# 13/13 [==============================] - ETA: 0s - loss: 0.2476 - dice_loss: 0.2489
# Epoch 00004: val_dice_loss did not improve from 0.29238
# 13/13 [==============================] - 1s 110ms/step - loss: 0.2476 - dice_loss: 0.2489 - val_loss: 0.4107 - val_dice_loss: 0.4107
# Epoch 5/500
# 13/13 [==============================] - ETA: 0s - loss: 0.2009 - dice_loss: 0.2008
# Epoch 00005: val_dice_loss did not improve from 0.29238
# 13/13 [==============================] - 1s 110ms/step - loss: 0.2009 - dice_loss: 0.2008 - val_loss: 0.4559 - val_dice_loss: 0.4559
# Epoch 6/500
# 13/13 [==============================] - ETA: 0s - loss: 0.1688 - dice_loss: 0.1687
# Epoch 00006: val_dice_loss did not improve from 0.29238
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1688 - dice_loss: 0.1687 - val_loss: 0.7674 - val_dice_loss: 0.7674
# Epoch 7/500
# 13/13 [==============================] - ETA: 0s - loss: 0.1483 - dice_loss: 0.1478
# Epoch 00007: val_dice_loss did not improve from 0.29238
# 13/13 [==============================] - 1s 111ms/step - loss: 0.1483 - dice_loss: 0.1478 - val_loss: 0.8225 - val_dice_loss: 0.8225
# Epoch 8/500
# 13/13 [==============================] - ETA: 0s - loss: 0.1373 - dice_loss: 0.1374
# Epoch 00008: val_dice_loss did not improve from 0.29238
# 13/13 [==============================] - 1s 109ms/step - loss: 0.1373 - dice_loss: 0.1374 - val_loss: 0.8714 - val_dice_loss: 0.8714
# Epoch 9/500
# 13/13 [==============================] - ETA: 0s - loss: 0.1360 - dice_loss: 0.1365
# Epoch 00009: val_dice_loss did not improve from 0.29238
# 13/13 [==============================] - 1s 110ms/step - loss: 0.1360 - dice_loss: 0.1365 - val_loss: 0.7360 - val_dice_loss: 0.7360
# Epoch 10/500
# 13/13 [==============================] - ETA: 0s - loss: 0.1459 - dice_loss: 0.1455
# Epoch 00010: val_dice_loss improved from 0.29238 to 0.23027, saving model to /content/drive/My Drive/SkySpecs/507_1.h5
# 13/13 [==============================] - 3s 214ms/step - loss: 0.1459 - dice_loss: 0.1455 - val_loss: 0.2303 - val_dice_loss: 0.2303
# Epoch 11/500
# 13/13 [==============================] - ETA: 0s - loss: 0.1327 - dice_loss: 0.1326
# Epoch 00011: val_dice_loss improved from 0.23027 to 0.20409, saving model to /content/drive/My Drive/SkySpecs/507_1.h5
# 13/13 [==============================] - 2s 152ms/step - loss: 0.1327 - dice_loss: 0.1326 - val_loss: 0.2041 - val_dice_loss: 0.2041
# Epoch 12/500
# 13/13 [==============================] - ETA: 0s - loss: 0.
val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 1s 114ms/step - loss: 1.6469e-04 - dice_loss: 1.6389e-04 - val_loss: 0.1580 - val_dice_loss: 0.1580
# Epoch 494/500
# 13/13 [==============================] - ETA: 0s - loss: 1.9067e-04 - dice_loss: 1.8851e-04
# Epoch 00494: val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 2s 116ms/step - loss: 1.9067e-04 - dice_loss: 1.8851e-04 - val_loss: 0.1593 - val_dice_loss: 0.1593
# Epoch 495/500
# 13/13 [==============================] - ETA: 0s - loss: 1.7558e-04 - dice_loss: 1.7977e-04
# Epoch 00495: val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 2s 116ms/step - loss: 1.7558e-04 - dice_loss: 1.7977e-04 - val_loss: 0.1531 - val_dice_loss: 0.1531
# Epoch 496/500
# 13/13 [==============================] - ETA: 0s - loss: 1.8151e-04 - dice_loss: 1.8060e-04
# Epoch 00496: val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 2s 117ms/step - loss: 1.8151e-04 - dice_loss: 1.8060e-04 - val_loss: 0.1528 - val_dice_loss: 0.1528
# Epoch 497/500
# 13/13 [==============================] - ETA: 0s - loss: 2.3272e-04 - dice_loss: 2.3206e-04
# Epoch 00497: val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 2s 116ms/step - loss: 2.3272e-04 - dice_loss: 2.3206e-04 - val_loss: 0.1576 - val_dice_loss: 0.1576
# Epoch 498/500
# 13/13 [==============================] - ETA: 0s - loss: 2.8696e-04 - dice_loss: 2.8434e-04
# Epoch 00498: val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 2s 117ms/step - loss: 2.8696e-04 - dice_loss: 2.8434e-04 - val_loss: 0.1534 - val_dice_loss: 0.1534
# Epoch 499/500
# 13/13 [==============================] - ETA: 0s - loss: 2.2657e-04 - dice_loss: 2.2463e-04
# Epoch 00499: val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 1s 115ms/step - loss: 2.2657e-04 - dice_loss: 2.2463e-04 - val_loss: 0.1555 - val_dice_loss: 0.1555
# Epoch 500/500
# 13/13 [==============================] - ETA: 0s - loss: 2.4337e-04 - dice_loss: 2.4348e-04
# Epoch 00500: val_dice_loss did not improve from 0.13043
# 13/13 [==============================] - 1s 112ms/step - loss: 2.4337e-04 - dice_loss: 2.4348e-04 - val_loss: 0.1562 - val_dice_loss: 0.1562

# %%
model.save('/content/drive/My Drive/SkySpecs/507_1.h5') # Save the model to drive/disk

# %% [markdown]
# **RESULTS**
# The best performing model acheived an accuracy of 99.81% on the training set and 92.26% on the validation set.

# %%
#Plot the 'loss vs epoch' graph for training and validation
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(EPOCHS)
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
#Result of the model from testing set
index = 1
val_preds = model.predict(x_test[index].reshape(1,img_size,img_size,3))
val_preds = val_preds.reshape(img_size,img_size)
for i in range(val_preds.shape[0]):
  for j in range(val_preds.shape[1]):
    if val_preds[i][j]>0.5:
      val_preds[i][j] = 255
    else:
      val_preds[i][j] = 0
plt.subplot(1, 2, 1)    
plt.title('Predicted Output')  
plt.imshow(val_preds)
plt.subplot(1, 2, 2)
plt.title('Ground Truth')
plt.imshow(y_test[index])

# %%
#Result of the model from testing set 
index = 2
val_preds = model.predict(x_test[index].reshape(1,img_size,img_size,3))
val_preds = val_preds.reshape(img_size,img_size)
for i in range(val_preds.shape[0]):
  for j in range(val_preds.shape[1]):
    if val_preds[i][j]>0.5:
      val_preds[i][j] = 255
    else:
      val_preds[i][j] = 0
plt.subplot(1, 2, 1)    
plt.title('Predicted Output')  
plt.imshow(val_preds)
plt.subplot(1, 2, 2)
plt.title('Ground Truth')
plt.imshow(y_test[index])

# %%
#Result of the model from testing set
index = 15
val_preds = model.predict(x_test[index].reshape(1,img_size,img_size,3))
val_preds = val_preds.reshape(img_size,img_size)
for i in range(val_preds.shape[0]):
  for j in range(val_preds.shape[1]):
    if val_preds[i][j]>0.5:
      val_preds[i][j] = 255
    else:
      val_preds[i][j] = 0
plt.subplot(1, 2, 1)    
plt.title('Predicted Output')  
plt.imshow(val_preds)
plt.subplot(1, 2, 2)
plt.title('Ground Truth')
plt.imshow(y_test[index])

# %% [markdown]
# From the predictions on testset we can see that model started to identify the wind turbines but definitely need to improve a lot. Training the model using additional images could improve the results and also finding the right loss function will make a huge difference.

# %%
#Find convex hull and draw convex hull with maximum area. This helps to remove the small noisy areas in the image
def find_hull(prediction):  # Input the segmented image from the model. Function outputs the convex hull with maximum area.
    prediction = prediction.astype(np.uint8) 
    contours, hierarchy = cv2.findContours(prediction, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) # Find contours using opencv
    hull = []
    for i in range(len(contours)): # Find convex hull for each contour set
        hull.append(cv2.convexHull(contours[i], False))
    drawing = np.zeros((prediction.shape[0], prediction.shape[1], 3)) # Create an empty black image
    color = (255, 255, 255) # hull color
    c = max(hull, key = cv2.contourArea) # Find hull with maximum area
    m = []
    m.append(c)
    cv2.drawContours(drawing, m, -1, color,thickness = cv2.FILLED) 
    plt.title(' Convex Hull')
    plt.imshow(drawing)
    return drawing

hull = find_hull(val_preds)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Testing the model on a different dataset - DTU - Drone inspection images of wind turbine from https://data.mendeley.com/datasets/hd96prn3nc/2
def test_model(img_path): #Input - test image path
    img = cv2.imread(img_path)
    img = cv2.resize(img,(224,224))
    plt.subplot(1, 3, 1)  
    plt.title('Input Image')    
    plt.imshow(img)
    img = img/255
    val_preds = model.predict(img.reshape(1,img_size,img_size,3))
    val_preds = val_preds.reshape(224,224)
    for i in range(val_preds.shape[0]):
      for j in range(val_preds.shape[1]):
        if val_preds[i][j]>0.5: # Keep only the pixels with value greater than 0.5
          val_preds[i][j] = 255
        else:
          val_preds[i][j] = 0
    plt.subplot(1, 3, 2)  
    plt.title(' Predicted Output')    
    plt.imshow(val_preds)
    pred = copy.deepcopy(val_preds)
    hull = []
    plt.subplot(1, 3, 3)
    hull = find_hull(pred)
    plt.title('Convex Hull')
    plt.imshow(hull)  
img_path = '/content/drive/My Drive/SkySpecs/DJI_0343.JPG'
test_model(img_path)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_path = '/content/drive/My Drive/SkySpecs/DJI_0616.JPG'
test_model(img_path)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_path = '/content/drive/My Drive/SkySpecs/DJI_0689.JPG'
test_model(img_path)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Future Work**
# 1. Using a large network like Mask_RCNN, DeepLab, FastFCN which supports larger images will improve the segmentation results, but requires higher computation memory. But these models will be hard to implement on mobile devices and drones.
# 2. Using different loss functions like Focal Loss, Dice Loss or IoU Loss could also improve the results further.
# 3. A depth estimation network can be used with the model to differentiate the wind turbine from the base of windmill.
